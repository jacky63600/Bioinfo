# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dengue_CN.csv')
df.head()
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           發病日 個案研判日         通報日 性別    年齡層 居住縣市 居住鄉鎮  居住村里          最小統計區  \
# 0  1998/01/02  None  1998/01/07  男  40-44  屏東縣  屏東市  None  A1320-0136-00
# 1  1998/01/03  None  1998/01/14  男  30-34  屏東縣  東港鎮  None  A1303-0150-00
# 2  1998/01/13  None  1998/02/18  男  55-59  宜蘭縣  宜蘭市  None  A0201-0449-00
# 3  1998/01/15  None  1998/01/23  男  35-39  高雄市  苓雅區  None  A6408-0153-00
# 4  1998/01/20  None  1998/02/04  男  55-59  宜蘭縣  五結鄉  None  A0209-0232-00
#
#        最小統計區中心點X  ... 是否境外移入  感染國家 確定病例數 居住村里代碼 感染村里代碼   血清型 內政部居住縣市代碼  \
# 0  120.505898941  ...      否  None     1   None   None  None     10013
# 1  120.453657460  ...      是  None     1   None   None   第二型     10013
# ...

# %%
df.shape
# Out:
# (79726, 26)

# %%
df.iloc[0]
# Out:
# 發病日             1998/01/02
# 個案研判日                 None
# 通報日             1998/01/07
# 性別                       男
# 年齡層                  40-44
# 居住縣市                   屏東縣
# 居住鄉鎮                   屏東市
# 居住村里                  None
# 最小統計區        A1320-0136-00
# 最小統計區中心點X    120.505898941
# 最小統計區中心點Y     22.464206650
# 一級統計區         A1320-04-008
# 二級統計區             A1320-04
# 感染縣市                  None
# 感染鄉鎮                  None
# 感染村里                  None
# 是否境外移入                   否
# 感染國家                  None
# 確定病例數                    1
# 居住村里代碼                None
# 感染村里代碼                None
# 血清型                   None
# 內政部居住縣市代碼            10013
# 內政部居住鄉鎮代碼          1001301
# 內政部感染縣市代碼             None
# 內政部感染鄉鎮代碼             None
# Name: 0, dtype: object
